# %%
# %pylab inline
from numpy.random import *
from numpy.linalg import *
from numpy import *
import matplotlib.pyplot as plot

# Supposons qu'un classifieur a un pourcentage d'erreur de :
p = 0.02

# Simulation du calcul de l'erreur sur plusieurs ensembles de tests de taille N_test
plot.subplots(figsize=(20,5))
for i,N_test in enumerate([10,100,1000,10000,100000]):
    # Simulation des erreurs de test, où chaque colonne est un ensemble de test différent
    N_ensemble_tests = 1000
    erreurs = rand(N_test,N_ensemble_tests) < p
    erreurs_par_ensemble = erreurs.mean(axis=0)
    print "N_test =",N_test
    print "Écart-type des erreurs moyennes par ensemble:",std(erreurs_par_ensemble)
    print "Standard error pour le premier ensemble:",std(erreurs[:,0])/sqrt(N_test)
    print ""
    plot.subplot(1,5,i+1)
    hist(erreurs_par_ensemble,20)
# Out:
# Welcome to pylab, a matplotlib-based Python environment [backend: module://IPython.kernel.zmq.pylab.backend_inline].
# For more information, type 'help(pylab)'.
# N_test = 10
# Écart-type des erreurs moyennes par ensemble: 0.0419899988092
# Standard error pour le premier ensemble: 0.0
#
# N_test =
#  100
# Écart-type des erreurs moyennes par ensemble: 0.0140808771034
# Standard error pour le premier ensemble: 0.00994987437107
#
# N_test =
#  1000
# Écart-type des erreurs moyennes par ensemble: 0.00435485005482
# Standard error pour le premier ensemble: 0.00420428352993
#
# N_test =
#  10000
# Écart-type des erreurs moyennes par ensemble: 0.00139679446949
# Standard error pour le premier ensemble: 0.00131858674345
#
# N_test =
#  100000
# Écart-type des erreurs moyennes par ensemble: 0.000452381363011
# Standard error pour le premier ensemble: 0.000445958630369
